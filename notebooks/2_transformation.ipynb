# %% [markdown]
# ## 🧹 3. Limpieza de datos
#
# En esta sección se realiza una limpieza mínima pero estructurada del dataset, centrada en garantizar la coherencia de los datos.
#
# - Los nombres de las columnas se convertirán a **minúsculas** para mantener consistencia y facilitar el acceso.
#
# - Se validará que los valores de las columnas **numéricas** estén dentro de rangos lógicos y no presenten valores negativos ni incoherentes.
#
# - Se revisarán los valores únicos de las columnas **categóricas** para detectar posibles inconsistencias con respecto a la documentación oficial.
# No se aplicará limpieza automática sobre estas categorías, pero se documentarán las observaciones relevantes.

# %%
# Importar librerías
import pandas as pd

# Importar archivo con funciones
import sys, os
sys.path.append("../src/")
import cleaning

# %%
# Cargar del dataset
df = pd.read_csv("../data/student_performance.csv")

# %% [markdown]
# ## 3.1 Realizamos la limpieza sobre el dataset
# Llamaremos a la funcion `clean_dataset` de nuestro archivo **cleaning.py**.

# %%
cleaning.clean_dataset(df)
# Out:
#       hours_studied  attendance parental_involvement access_to_resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      extracurricular_activities  sleep_hours  previous_scores  \
# ...

# %% [markdown]
# ## 🔍 Comprobaciones despues de la limpieza

# %% [markdown]
# ### 3.1 Normalización de nombres de columnas
#
# Para facilitar el acceso a las columnas y mantener la coherencia del código,
# se van a convertir todos los nombres de las columnas a **minúsculas**.

# %%
df.head()
# Out:
#    hours_studied  attendance parental_involvement access_to_resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   extracurricular_activities  sleep_hours  previous_scores motivation_level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   internet_access  tutoring_sessions family_income teacher_quality  \
# ...

# %% [markdown]
# ### 3.2 Valores Nulos
# Aunque se han detectado valores nulos en algunas columnas categóricas, no se realizará imputación, siguiendo las recomendaciones del profesor.
# Las visualizaciones posteriores se basarán únicamente en los registros completos.

# %% [markdown]
# ### 3.3 Revisión de rangos y coherencia
#
# Además de la limpieza básica, es importante verificar que los valores del dataset sean **coherentes y estén dentro de rangos lógicos**.
#
# En esta sección se revisará:
#
# - Que las variables numéricas (`attendance`, `sleep_hours`, `hours_studied`, `tutoring_sessions`, `physical_activity`, `exam_score`, `previous_scores`) no tengan valores fuera de rango o negativos.
#
# - Que las variables categóricas (`gender`, `school_type`, `teacher_quality`, etc.) contengan únicamente las categorías definidas en la documentación oficial.

# %%
cleaning.coherence_ranges(df)
# Out:
# % Asistencia fuera de rango: 0
# Horas de sueño fuera de rango: 0
# Horas de estudio negativas: 0
# Sesiones de tutoría negativas: 0
# Actividad física semanal negativas: 0
# Notas de Examen fuera de rango: 1
# Puntuaciones de examen anteriores fuera de rango: 0
# parental_involvement: ['Low' 'Medium' 'High']
# access_to_resources: ['High' 'Medium' 'Low']
# extracurricular_activities: ['No' 'Yes']
# motivation_level: ['Low' 'Medium' 'High']
# internet_access: ['Yes' 'No']
# family_income: ['Low' 'Medium' 'High']
# teacher_quality: ['Medium' 'High' 'Low' nan]
# school_type: ['Public' 'Private']
# peer_influence: ['Positive' 'Negative' 'Neutral']
# learning_disabilities: ['No' 'Yes']
# parental_education_level: ['High School' 'College' 'Postgraduate' nan]
# distance_from_home: ['Near' 'Moderate' 'Far' nan]
# gender: ['Male' 'Female']

# %% [markdown]
# ### 3.3.1 Corrección puntual en `exam_score`
# Se ha detectado un valor fuera de rango en la columna `exam_score`

# %%
df[~df["exam_score"].between(0, 100)]
# Out:
#       hours_studied  attendance parental_involvement access_to_resources  \
# 1525             27          98                  Low              Medium
#
#      extracurricular_activities  sleep_hours  previous_scores  \
# 1525                        Yes            6               93
#
#      motivation_level internet_access  tutoring_sessions family_income  \
# 1525              Low              No                  5          High
#
#      teacher_quality school_type peer_influence  physical_activity  \
# 1525            High      Public       Positive                  3
#
#      learning_disabilities parental_education_level distance_from_home  \
# 1525                    No              High School           Moderate
#
#       gender  exam_score
# 1525  Female         101

# %% [markdown]
# #### Registro con valor **101** en el `índice 1525`.
#
# ➡️ Esta corrección puntual se realiza de forma explícita.
#
# Dado que el rango válido es de **0 a 100**, se ha corregirá manualmente a **100** para preservar la coherencia del análisis.

# %%
df.loc[1525, "exam_score"] = 100

# %%
# Volvemos a mirar que ya NO haya valores fuera de rango
df[~df["exam_score"].between(0, 100)]
# Out:
# Empty DataFrame
# Columns: [hours_studied, attendance, parental_involvement, access_to_resources, extracurricular_activities, sleep_hours, previous_scores, motivation_level, internet_access, tutoring_sessions, family_income, teacher_quality, school_type, peer_influence, physical_activity, learning_disabilities, parental_education_level, distance_from_home, gender, exam_score]
# Index: []

# %% [markdown]
# ### Guardamos el dataset limpio en otro dataset

# %%
df_limpio = cleaning.clean_dataset(df)
df_limpio.to_csv("../data/student_clean.csv", index=False)

# %% [markdown]
# ## ✅ Limpieza completada
#
# Se ha realizado una limpieza completa del dataset, incluyendo:
#
# - Normalización de nombres de columnas a **minúsculas**para facilitar el acceso y mantener coherencia.
# - Verificación de rangos en variables numéricas para asegurar que no existan valores negativos ni fuera de los límites esperados.
# - Revisión de valores únicos en variables `categóricas` para detectar posibles inconsistencias con respecto a la documentación oficial.
# - Corrección puntual de un valor fuera de rango en la columna exam_score (registro con valor 101 corregido a 100).
# - Se ha generado un nuevo dataset con los datos limpios llamado **student_clean.csv**.
#
# Con estos pasos, el dataset queda listo para la fase de **visualización** en el notebook `3_eda.ipynb`, manteniendo la integridad de los datos y documentando claramente las correcciones realizadas.
